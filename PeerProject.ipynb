# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Alara Uzun**

# %% [markdown]
# Business Intelligence Analyst

# %% [markdown]
# *I am interested in data science because I want to excel at my job utilizing data analytics.*

# %% [markdown]
# ### This code will add the values together.

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1. Business
# 2. Intelligence
# 3. Data
# ***
# - Bulleted item
# - Bulleted item
# ***
# __[IBM](https://www.ibm.com/uk-en)__
